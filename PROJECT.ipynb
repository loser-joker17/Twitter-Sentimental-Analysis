# %%
import numpy as np
import pandas as pd

# %%
#np.loadtxt("0000000000002747_training_twitter_x_y_train.csv")
#text=.raw("0000000000002747_training_twitter_x_y_train.csv")
data=pd.read_csv("0000000000002747_training_twitter_x_y_train.csv")
data_test=pd.read_csv("0000000000002747_test_twitter_x_test.csv")

# %%
b=data["airline_sentiment"]
#b_test=data_test["airline_sentiment"]

# %%
a=data["text"]
a_test=data_test["text"]
a, b,a_test
# Out:
# (0        @SouthwestAir I am scheduled for the morning, ...
#  1        @SouthwestAir seeing your workers time in and ...
#  2        @united Flew ORD to Miami and back and  had gr...
#  3           @SouthwestAir @dultch97 that's horse radish 😤🐴
#  4        @united so our flight into ORD was delayed bec...
#                                 ...
#  10975                              @AmericanAir followback
#  10976    @united thanks for the help. Wish the phone re...
#  10977    @usairways the. Worst. Ever. #dca #customerser...
#  10978    @nrhodes85: look! Another apology. DO NOT FLY ...
#  10979    @united you are by far the worst airline. 4 pl...
#  Name: text, Length: 10980, dtype: object,
#  0        negative
#  1        positive
#  2        positive
#  3        negative
#  4        negative
#             ...
#  10975     neutral
#  10976    positive
#  10977    negative
#  10978    negative
#  10979    negative
#  Name: airline_sentiment, Length: 10980, dtype: object,
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
document=[]
for x in a:
    document.append(word_tokenize(x))
doc_test=[]
for x in a_test:
    doc_test.append(word_tokenize(x))

# %%
document[0], doc_test[0]
# Out:
# (['@',
#   'SouthwestAir',
#   'I',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes',
#   '..',
#   'not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  ['@',
#   'AmericanAir',
#   'In',
#   'car',
#   'gng',
#   'to',
#   'DFW',
#   '.',
#   'Pulled',
#   'over',
#   '1hr',
#   'ago',
#   '-',
#   'very',
#   'icy',
#   'roads',
#   '.',
#   'On-hold',
#   'with',
#   'AA',
#   'since',
#   '1hr',
#   '.',
#   'Ca',
#   "n't",
#   'reach',
#   'arpt',
#   'for',
#   'AA2450',
#   '.',
#   'Wat',
#   '2',
#   'do',
#   '?'])

# %%
categories=[]
for x in b:
    categories.append(word_tokenize(x)[0])

# %%
categories
# Out:
# ['negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
# ...

# %%
documents=[]
i=0
while i<len(categories):
    documents.append((document[i],categories[i]))
    i=i+1

# %%
documents[0]
# Out:
# (['@',
#   'SouthwestAir',
#   'I',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes',
#   '..',
#   'not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  'negative')

# %%
from nltk.corpus import stopwords
stops=set(stopwords.words("english"))
import string
punctuations=list(string.punctuation)
stops.update(punctuations)
stops
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
def get_simple_pos(tag):
    if tag.startswith("J"):
        return wordnet.ADJ
    elif tag.startswith("V"):
        return wordnet.VERB
    elif tag.startswith("N"):
        return wordnet.NOUN
    elif tag.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def clean_data(words):
    output_words=[]
    for w in words:
        if w.lower() not in stops:
            pos=pos_tag(w)
            clean_word=lemmatizer.lemmatize(w, pos=get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
documents=[(clean_data(document),category) for document, category in documents]

# %%
doc_test=[clean_data(document) for document in doc_test]

# %%
documents[0], doc_test[0]
# Out:
# ((['southwestair',
#    'scheduled',
#    'morning',
#    '2',
#    'days',
#    'fact',
#    'yes',
#    '..',
#    'sure',
#    'evening',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'),
#  ['americanair',
#   'car',
#   'gng',
#   'dfw',
#   'pulled',
#   '1hr',
#   'ago',
#   'icy',
#   'road',
#   'on-hold',
#   'aa',
#   'since',
#   '1hr',
#   'ca',
#   "n't",
#   'reach',
#   'arpt',
#   'aa2450',
#   'wat',
#   '2'])

# %% [markdown]
# # Building Feature Set

# %%
all_words=[]
for doc in documents:
    all_words+=doc[0]

# %%
all_words
# Out:
# ['southwestair',
#  'scheduled',
#  'morning',
#  '2',
#  'days',
#  'fact',
#  'yes',
#  '..',
#  'sure',
#  'evening',
#  'flight',
#  'one',
#  'cancelled',
#  'flightled',
#  'southwestair',
#  'seeing',
#  'worker',
#  'time',
#  'time',
#  'going',
#  'beyond',
#  'love',
#  'flying',
#  'guy',
#  'thank',
#  'united',
#  'flew',
#  'ord',
#  'miami',
#  'back',
#  'great',
#  'crew',
#  'service',
#  'leg',
#  'thanks',
#  'southwestair',
#  'dultch97',
#  "'s",
#  'horse',
#  'radish',
#  '😤🐴',
#  'united',
#  'flight',
#  'ord',
#  'delayed',
#  'air',
#  'force',
#  'one',
#  'last',
#  'flight',
#  'sbn',
#  '8:20',
#  '5',
#  'min',
#  'landed',
#  'united',
#  'load',
#  'us',
#  'flying',
#  'sardine',
#  'knew',
#  'pilot',
#  '2',
#  'hour',
#  'late',
#  'flight',
#  'incompetent',
#  'beyond',
#  'belief',
#  'jetblue',
#  'stock',
#  'response',
#  'delays',
#  'frustrating',
#  'poor',
#  'cust',
#  'serv',
#  'amp',
#  'told',
#  '3',
#  'ppl',
#  'wait',
# ...

# %%
import nltk
Freq = nltk.FreqDist(all_words)
Freq
# Out:
# FreqDist({'united': 3180, 'flight': 2902, 'usairways': 2253, 'americanair': 2235, 'southwestair': 1841, 'jetblue': 1762, "n't": 1535, "'s": 1113, 'get': 1019, 'http': 906, ...})

# %%
common=Freq.most_common(15)
common
# Out:
# [('united', 3180),
#  ('flight', 2902),
#  ('usairways', 2253),
#  ('americanair', 2235),
#  ('southwestair', 1841),
#  ('jetblue', 1762),
#  ("n't", 1535),
#  ("'s", 1113),
#  ('get', 1019),
#  ('http', 906),
#  ('hour', 863),
#  ('thanks', 829),
#  ('cancelled', 800),
#  ('service', 738),
#  ('customer', 701)]

# %%
features=[ i[0] for i in common]
features
# Out:
# ['united',
#  'flight',
#  'usairways',
#  'americanair',
#  'southwestair',
#  'jetblue',
#  "n't",
#  "'s",
#  'get',
#  'http',
#  'hour',
#  'thanks',
#  'cancelled',
#  'service',
#  'customer']

# %%
def get_feature_dict(words):
    current_features={}
    words_set=set(words)
    for w in features:
        current_features[w]=w in words_set
    return current_features

# %%
training_data=[(get_feature_dict(doc),category) for doc, category in documents]

# %%
training_data[0]
# Out:
# ({'united': False,
#   'flight': True,
#   'usairways': False,
#   'americanair': False,
#   'southwestair': True,
#   'jetblue': False,
#   "n't": False,
#   "'s": False,
#   'get': False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': True,
#   'service': False,
#   'customer': False},
#  'negative')

# %% [markdown]
# # Classification Using NLTK Naive Bayes

# %%
from nltk import NaiveBayesClassifier
classifier=NaiveBayesClassifier.train(training_data)

# %%
#y_pred=classifier.predict(doc_test)

# %%
#classifier.classify(doc_test)

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                     hour = True           negati : positi =     11.0 : 1.0
#                 customer = True           negati : neutra =      8.5 : 1.0
#                   thanks = True           positi : negati =      7.4 : 1.0
#                cancelled = True           negati : positi =      6.1 : 1.0
#                      n't = True           negati : positi =      4.0 : 1.0
#                  service = True           negati : neutra =      3.9 : 1.0
#                     http = True           neutra : negati =      3.3 : 1.0
#                  jetblue = True           neutra : negati =      2.3 : 1.0
#                usairways = True           negati : positi =      2.3 : 1.0
#                      get = True           negati : positi =      2.2 : 1.0
#                   flight = True           negati : positi =      2.0 : 1.0
#             southwestair = True           positi : negati =      1.9 : 1.0
# ...

# %%
training_data[0], doc_test[0]
# Out:
# (({'united': False,
#    'flight': True,
#    'usairways': False,
#    'americanair': False,
#    'southwestair': True,
#    'jetblue': False,
#    "n't": False,
#    "'s": False,
#    'get': False,
#    'http': False,
#    'hour': False,
#    'thanks': False,
#    'cancelled': True,
#    'service': False,
#    'customer': False},
#   'negative'),
#  ['americanair',
#   'car',
#   'gng',
#   'dfw',
#   'pulled',
#   '1hr',
#   'ago',
#   'icy',
#   'road',
#   'on-hold',
#   'aa',
#   'since',
#   '1hr',
#   'ca',
#   "n't",
#   'reach',
#   'arpt',
#   'aa2450',
#   'wat',
#   '2'])

# %%
import nltk
w=[]
for x in doc_test:
    Freq = nltk.FreqDist(x)
    #t=get_feature_dict(Freq)
    w.append(classifier.classify(Freq))

# %%
w
# Out:
# ['negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
# ...

# %%
testing_data_a=[]
i=0
while i<len(w):
    testing_data_a.append((doc_test[i],w[i]))
    i=i+1

# %%
testing_data_a[0]
#,len(doc_test), len(w)
testing_data=[(get_feature_dict(doc),category) for doc, category in testing_data_a]

# %%
training_data[0],testing_data[0]
# Out:
# (({'united': False,
#    'flight': True,
#    'usairways': False,
#    'americanair': False,
#    'southwestair': True,
#    'jetblue': False,
#    "n't": False,
#    "'s": False,
#    'get': False,
#    'http': False,
#    'hour': False,
#    'thanks': False,
#    'cancelled': True,
#    'service': False,
#    'customer': False},
#   'negative'),
#  ({'united': False,
#    'flight': False,
#    'usairways': False,
#    'americanair': True,
#    'southwestair': False,
#    'jetblue': False,
#    "n't": True,
#    "'s": False,
#    'get': False,
#    'http': False,
#    'hour': False,
#    'thanks': False,
#    'cancelled': False,
#    'service': False,
#    'customer': False},
#   'negative'))

# %%
nltk.classify.accuracy(classifier,testing_data)
# Out:
# 0.8199453551912569

# %% [markdown]
# # Using SKLearn Classifier

# %%
from sklearn.svm import SVC
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc=SVC()

# %%
classifier_sklearn=SklearnClassifier(svc)

# %%
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC())>

# %%
#for a in doc_test:
#classifier_sklearn.classify()
#import nltk
u=[]
for x in doc_test:
    Freq = nltk.FreqDist(x)
    #t=get_feature_dict(Freq)
    u.append(classifier_sklearn.classify(Freq))

# %%
#a_test
u
# Out:
# ['negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
# ...

# %%
testing_data_b=[]
i=0
while i<len(u):
    testing_data_b.append((doc_test[i],u[i]))
    i=i+1

# %%
testing_data2=[(get_feature_dict(doc),category) for doc, category in testing_data_b]

# %%
testing_data2[0]
# Out:
# ({'united': False,
#   'flight': False,
#   'usairways': False,
#   'americanair': True,
#   'southwestair': False,
#   'jetblue': False,
#   "n't": True,
#   "'s": False,
#   'get': False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': False,
#   'service': False,
#   'customer': False},
#  'negative')

# %%
pred1=pd.DataFrame(w)
pred1.to_csv("pred1.csv")

# %%
pred2=pd.DataFrame(u)
pred2.to_csv("pred2.csv")
